# %% [markdown]
# # **SPOT-your-FI pt- 2**

# %% [markdown]
# ## Libraries

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup as bs
from time import sleep
from urllib import request
import requests
import re
import pandas as pd
import time
# Out:
# C:\Users\aggar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\requests\__init__.py:104: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## Lyrics Extractor

# %%
billboard = pd.read_csv("TOP 100 Eng_Linkedin.csv")
url = "https://www.azlyrics.com/lyrics/{}/{}.html"
file = "lyrics.txt"

for index, row in billboard.iterrows():
    artist = row['artistNamethe']
    song = row['SongNameClean']
    artist = artist.replace(" ","")
    song.replace(' ', '')
    s = re.sub(r"\s","",song).lower() 
    

    try:
            
        with open(file,"a") as fi:
            f_url = url.format(artist,s)
            print(f_url)
            html_page = urllib.request.urlopen(f_url).read()
            soup = bs(html_page,'html.parser')
            html_pointer = soup.find('div', attrs={'class':'ringtone'})
            song_name = html_pointer.find_next('b').contents[0].strip()
            lyrics = html_pointer.find_next('div').text.strip()
            
            fi.write("==="+song_name+"===")
            fi.write("\n\n")
            fi.write(lyrics)
            
            fi.write("\n\n")
            time.sleep(1)
            print("Lyrics successfully written to file for : " + song_name)
            
    except:
        print(song_name+ "not found")
# Out:
# https://www.azlyrics.com/lyrics/beforeyouexit/silence.html
# Lyrics successfully written to file for : "Silence"
# https://www.azlyrics.com/lyrics/imaginedragons/enemy.html
# Lyrics successfully written to file for : "Enemy"
# https://www.azlyrics.com/lyrics/imaginedragons/boomerang.html
# Lyrics successfully written to file for : "Boomerang"
# https://www.azlyrics.com/lyrics/cab/lockmeup.html
# Lyrics successfully written to file for : "Lock Me Up"
# https://www.azlyrics.com/lyrics/imaginedragons/idontknowwhy.html
# Lyrics successfully written to file for : "I Don't Know Why"
# https://www.azlyrics.com/lyrics/socialhouse/magicinthehamptons.html
# Lyrics successfully written to file for : "Magic In The Hamptons"
# https://www.azlyrics.com/lyrics/boywithuke/twomoons.html
# Lyrics successfully written to file for : "Two Moons"
# https://www.azlyrics.com/lyrics/whydontwe/stay.html
# Lyrics successfully written to file for : "Stay"
# https://www.azlyrics.com/lyrics/johnk/parachute.html
# ...
